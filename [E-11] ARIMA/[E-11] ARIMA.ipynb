# %% [markdown]
# # [E-11] ARIMA

# %% [markdown]
# > 목차
# -
#
#
# **1. 개요**
#
#     1.1 프로젝트 과정 및 목표
#     1.2 예상되는 문제점
#     1.3 용어 및 라이브러리
#
# **2. 루브릭 평가기준**
#
# **3. Project**
#
#     3.1. 시계열 데이터 준비
#     3.2. 각종 전처리 수행
#     3.3. 시계열 안정성 분석
#     3.4. 학습, 테스트 데이터셋 생성
#     3.5. 적정 ARIMA 모수 찾기
#     3.6. ARIMA 모델 훈련과 테스트
#     3.7. 다른 주식 종목 예측해 보기
# **4. 회고**
#
#     4.1 결과 평가
#     4.2 어려웠던 점

# %% [markdown]
# ---
# > **1. 개요**
# -

# %% [markdown]
# > **1.1 프로젝트 과정 및 목표**

# %% [markdown]
# **<프로젝트 과정>**
# 1. 시계열 데이터 준비
# 2. 각종 전처리 수행
# 3. 시계열 안정성 분석
# 4. 학습, 테스트 데이터셋 생성
# 5. 적정 ARIMA 모수 찾기
# 6. ARIMA 모델 훈련과 테스트
# 7. 다른 주식 종목 예측해 보기

# %% [markdown]
# > **1.2 예상되는 문제점**

# %% [markdown]
# + 주가 하락장이나 상승장이 꾸준히 이어진게 아니라면 제대로 예측이 안될 가능성이 높다

# %% [markdown]
# > **1.3 용어**

# %% [markdown]
# + 시계열 : 시계열이란 시간 순서대로 발생한 데이터의 수열이라는 뜻
# + 귀무가설 : 처음부터 버릴 것을 예측하는 가설
# + 대립가설 : 귀무가설이 거짓이라면 대안적으로 참이되는 가설
# + p-value : 귀무가설이 참이라 가정했을 표본으로 얻어지는 통계치가 나타날 확률

# %% [markdown]
# ---
# > **2. 루브릭 평가기준**
# -

# %% [markdown]
# |평가문항 | 상세기준|
# |:---------|:---------|
# |1. 시계열의 안정성이 충분히 확인되었는가?| 플로팅과 adfuller 메소드가 모두 적절히 사용되었음|
# |2. ARIMA 모델 모수선택 근거를 체계적으로 제시하였는가?|p,q를 위한 ACF, PACF 사용과 d를 위한 차분 과정이 명확히 제시됨|
# |3. 예측 모델의 오차율이 기준 이하로 정확하게 나왔는가?|3개 이상 종목이 MAPE 15% 미만의 정확도로 예측됨|

# %% [markdown]
# ---
# > **3. Project**
# -

# %% [markdown]
# > 3.1. 시계열 데이터 준비

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os

dataset_filepath = os.getenv('HOME') + '/aiffel/stock_prediction/data/005930.KS.csv'
df = pd.read_csv(dataset_filepath, index_col='Date', parse_dates=True)
ts = df['Close']

ts.head()
# Out:
# Date
# 2020-05-18    48800.0
# 2020-05-19    50300.0
# 2020-05-20    50000.0
# 2020-05-21    49950.0
# 2020-05-22    48750.0
# Name: Close, dtype: float64

# %% [markdown]
# > 3.2. 각종 전처리 수행

# %%
# 결측치 처리
ts = ts.interpolate(method='time')
ts[ts.isna()]  # Time Series에서 결측치가 있는 부분만 Series로 출력합니다.
# Out:
# Series([], Name: Close, dtype: float64)

# %%
# 로그 변환 시도 
ts_log = np.log(ts)

# %%
from matplotlib.pylab import rcParams
rcParams['figure.figsize'] = 13, 6    # matlab 차트의 기본 크기를 13, 6으로 지정해 줍니다.

# 시계열(time series) 데이터를 차트로 그려 봅시다. 특별히 더 가공하지 않아도 잘 그려집니다.
plt.plot(ts)

# %%
# 결측치가 있다면 이를 보간합니다. 보간 기준은 time을 선택합니다. 
ts=ts.interpolate(method='time')

# 보간 이후 결측치(NaN) 유무를 다시 확인합니다.
print(ts[ts.isna()])

# 다시 그래프를 확인해봅시다!
plt.plot(ts)
# Out:
# Series([], Name: Close, dtype: float64)

# %% [markdown]
# > 3.3. 시계열 안정성 분석

# %%
# 구간의 평균 (이동평균) 과 표준편차(이동표준편차)
def plot_rolling_statistics(timeseries, window=12):
    
    rolmean = timeseries.rolling(window=window).mean()  # 이동평균 시계열
    rolstd = timeseries.rolling(window=window).std()    # 이동표준편차 시계열

     # 원본시계열, 이동평균, 이동표준편차를 plot으로 시각화해 본다.
    orig = plt.plot(timeseries, color='blue',label='Original')    
    mean = plt.plot(rolmean, color='red', label='Rolling Mean')
    std = plt.plot(rolstd, color='black', label='Rolling Std')
    plt.legend(loc='best')
    plt.title('Rolling Mean & Standard Deviation')
    plt.show(block=False)
    
print('슝=3')
# Out:
# 슝=3

# %%
from statsmodels.tsa.stattools import adfuller

def augmented_dickey_fuller_test(timeseries):
    # statsmodels 패키지에서 제공하는 adfuller 메서드를 호출합니다.
    dftest = adfuller(timeseries, autolag='AIC')  
    
    # adfuller 메서드가 리턴한 결과를 정리하여 출력합니다.
    print('Results of Dickey-Fuller Test:')
    dfoutput = pd.Series(dftest[0:4], index=['Test Statistic','p-value','#Lags Used','Number of Observations Used'])
    for key,value in dftest[4].items():
        dfoutput['Critical Value (%s)' % key] = value
    print(dfoutput)
    
print('슝=3')
# Out:
# 슝=3

# %%
# 정성적 그래프 분석
plot_rolling_statistics(ts_log, window=12)

#정량적 Augmented Dicky-Fuller Test
augmented_dickey_fuller_test(ts_log)

#시계열 분해 (Time Series Decomposition)
from statsmodels.tsa.seasonal import seasonal_decompose
decomposition = seasonal_decompose(ts_log, model='multiplicative', period = 30) 

trend = decomposition.trend
seasonal = decomposition.seasonal
residual = decomposition.resid

plt.subplot(411)
plt.plot(ts_log, label='Original')
plt.legend(loc='best')
plt.subplot(412)
plt.plot(trend, label='Trend')
plt.legend(loc='best')
plt.subplot(413)
plt.plot(seasonal,label='Seasonality')
plt.legend(loc='best')
plt.subplot(414)
plt.plot(residual, label='Residuals')
plt.legend(loc='best')
plt.tight_layout()
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                  -1.383525
# p-value                          0.590149
# #Lags Used                       0.000000
# Number of Observations Used    249.000000
# Critical Value (1%)             -3.456888
# Critical Value (5%)             -2.873219
# Critical Value (10%)            -2.572994
# dtype: float64

# %%
augmented_dickey_fuller_test(ts)
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                  -1.222649
# p-value                          0.663778
# #Lags Used                       0.000000
# Number of Observations Used    249.000000
# Critical Value (1%)             -3.456888
# Critical Value (5%)             -2.873219
# Critical Value (10%)            -2.572994
# dtype: float64

# %% [markdown]
# p-value가 0.66 이므로 아직 적합한 데이터가 아니다.

# %% [markdown]
# ### 로그함수로 변환

# %%
plt.plot(ts_log)

# %%
augmented_dickey_fuller_test(ts_log)
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                  -1.383525
# p-value                          0.590149
# #Lags Used                       0.000000
# Number of Observations Used    249.000000
# Critical Value (1%)             -3.456888
# Critical Value (5%)             -2.873219
# Critical Value (10%)            -2.572994
# dtype: float64

# %% [markdown]
# 여전히 p-value는 0.59로 좀 더 낮춰야 한다.

# %% [markdown]
# ### moving average 제거 추세 상쇄하기

# %%
moving_avg = ts_log.rolling(window=12).mean()  # moving average구하기 
plt.plot(ts_log)
plt.plot(moving_avg, color='red')

# %%
ts_log_moving_avg = ts_log - moving_avg # 변화량 제거
ts_log_moving_avg.head(15)
# Out:
# Date
# 2020-05-18         NaN
# 2020-05-19         NaN
# 2020-05-20         NaN
# 2020-05-21         NaN
# 2020-05-22         NaN
# 2020-05-25         NaN
# 2020-05-26         NaN
# 2020-05-27         NaN
# 2020-05-28         NaN
# 2020-05-29         NaN
# 2020-06-01         NaN
# 2020-06-02    0.028599
# 2020-06-03    0.077956
# 2020-06-04    0.072953
# 2020-06-05    0.080606
# Name: Close, dtype: float64

# %%
ts_log_moving_avg.dropna(inplace=True)
ts_log_moving_avg.head(15)
# Out:
# Date
# 2020-06-02    0.028599
# 2020-06-03    0.077956
# 2020-06-04    0.072953
# 2020-06-05    0.080606
# 2020-06-08    0.061862
# 2020-06-09    0.061925
# 2020-06-10    0.049636
# 2020-06-11    0.021446
# 2020-06-12   -0.019996
# 2020-06-15   -0.066141
# 2020-06-16   -0.025267
# 2020-06-17   -0.024961
# 2020-06-18   -0.024494
# 2020-06-19   -0.010603
# 2020-06-22   -0.023697
# Name: Close, dtype: float64

# %%
plot_rolling_statistics(ts_log_moving_avg)

# %%
augmented_dickey_fuller_test(ts_log_moving_avg)
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                  -4.163469
# p-value                          0.000759
# #Lags Used                       0.000000
# Number of Observations Used    238.000000
# Critical Value (1%)             -3.458128
# Critical Value (5%)             -2.873762
# Critical Value (10%)            -2.573283
# dtype: float64

# %% [markdown]
# 값이 이제 안정적으로 변함을 확인할 수 있지만 추가적으로 차분을 이용해서 계절성을 상쇄 해야 합니다.

# %% [markdown]
# ## 차분

# %%
ts_log_moving_avg_shift = ts_log_moving_avg.shift()

plt.plot(ts_log_moving_avg, color='blue')
plt.plot(ts_log_moving_avg_shift, color='green')

# %%
ts_log_moving_avg_diff = ts_log_moving_avg - ts_log_moving_avg_shift
ts_log_moving_avg_diff.dropna(inplace=True)
plt.plot(ts_log_moving_avg_diff)

# %%
plot_rolling_statistics(ts_log_moving_avg_diff)

# %%
augmented_dickey_fuller_test(ts_log_moving_avg_diff)
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                -1.546028e+01
# p-value                        2.711476e-28
# #Lags Used                     0.000000e+00
# Number of Observations Used    2.370000e+02
# Critical Value (1%)           -3.458247e+00
# Critical Value (5%)           -2.873814e+00
# Critical Value (10%)          -2.573311e+00
# dtype: float64

# %% [markdown]
# > 3.4. 학습, 테스트 데이터셋 생성

# %%
train_data, test_data = ts_log[:int(len(ts_log)*0.9)], ts_log[int(len(ts_log)*0.9):]
plt.figure(figsize=(10,6))
plt.grid(True)
plt.plot(ts_log, c='r', label='training dataset')  # train_data를 적용하면 그래프가 끊어져 보이므로 자연스러운 연출을 위해 ts_log를 선택
plt.plot(test_data, c='b', label='test dataset')
plt.legend()

# %%
print(ts_log[:2])
print(train_data.shape)
print(test_data.shape)
# Out:
# Date
# 2020-05-18    10.795486
# 2020-05-19    10.825760
# Name: Close, dtype: float64
# (225,)
# (25,)

# %% [markdown]
# > 3.5. 적정 ARIMA 모수 찾기

# %%
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf

plot_acf(ts_log)   # ACF : Autocorrelation 그래프 그리기
plot_pacf(ts_log)  # PACF : Partial Autocorrelation 그래프 그리기
plt.show()
# Out:
# /opt/conda/lib/python3.9/site-packages/statsmodels/graphics/tsaplots.py:348: FutureWarning: The default method 'yw' can produce PACF values outside of the [-1,1] interval. After 0.13, the default will change tounadjusted Yule-Walker ('ywm'). You can use this method now by setting method='ywm'.
#   warnings.warn(

# %% [markdown]
# 2번째 데이터부터 값들이 ACF 값은 2 이후에 점차 감소하며 PACF가 1 이후에 점차 0에 수렴 한다.

# %%
# 1차 차분 구하기
diff_1 = ts_log.diff(periods=1).iloc[1:]
diff_1.plot(title='Difference 1st')

augmented_dickey_fuller_test(diff_1)

# 혹시 필요한 경우 2차 차분 구하기
diff_2 = diff_1.diff(periods=1).iloc[1:]
diff_2.plot(title='Difference 2nd')

augmented_dickey_fuller_test(diff_2)
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                -1.553699e+01
# p-value                        2.183738e-28
# #Lags Used                     0.000000e+00
# Number of Observations Used    2.480000e+02
# Critical Value (1%)           -3.456996e+00
# Critical Value (5%)           -2.873266e+00
# Critical Value (10%)          -2.573019e+00
# dtype: float64
# Results of Dickey-Fuller Test:
# Test Statistic                -1.029320e+01
# p-value                        3.525823e-18
# #Lags Used                     7.000000e+00
# Number of Observations Used    2.400000e+02
# Critical Value (1%)           -3.457894e+00
# Critical Value (5%)           -2.873659e+00
# Critical Value (10%)          -2.573229e+00
# dtype: float64

# %% [markdown]
# 차분 없이 해도 p-value가 낮게 나오기 때문에 차분은 0으로 둔다.

# %% [markdown]
# >3.6. ARIMA 모델 훈련과 테스트

# %%
import warnings
warnings.filterwarnings('ignore') #경고 무시

from statsmodels.tsa.arima.model import ARIMA
# Build Model
model = ARIMA(train_data, order=(2, 0, 1)) # 모수는 이전 그래프를 참고 
fitted_m = model.fit() 

print(fitted_m.summary())
# Out:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                  Close   No. Observations:                  225
# Model:                 ARIMA(2, 0, 1)   Log Likelihood                 583.361
# Date:                Thu, 10 Feb 2022   AIC                          -1156.722
# Time:                        06:53:38   BIC                          -1139.642
# Sample:                             0   HQIC                         -1149.828
#                                 - 225
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         11.0896      0.129     86.277      0.000      10.838      11.342
# ar.L1          0.7739      1.821      0.425      0.671      -2.796       4.344
# ar.L2          0.2191      1.811      0.121      0.904      -3.331       3.769
# ma.L1          0.2595      1.813      0.143      0.886      -3.294       3.813
# sigma2         0.0003   2.56e-05     12.526      0.000       0.000       0.000
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.23   Jarque-Bera (JB):                20.44
# Prob(Q):                              0.63   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.95   Skew:                             0.50
# Prob(H) (two-sided):                  0.81   Kurtosis:                         4.08
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %%
# Forecast : 결과가 fc에 담깁니다. 
fc = fitted_m.forecast(len(test_data), alpha=0.05)  # 95% conf
fc = np.array(fc)
# Make as pandas series
fc_series = pd.Series(fc, index=test_data.index)   # 예측결과

# Plot
plt.figure(figsize=(10,5), dpi=100)
plt.plot(train_data, label='training')
plt.plot(test_data, c='b', label='actual price')
plt.plot(fc_series, c='r',label='predicted price')
plt.legend()
plt.show()

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error
import math

mse = mean_squared_error(np.exp(test_data), np.exp(fc))
print('MSE: ', mse)

mae = mean_absolute_error(np.exp(test_data), np.exp(fc))
print('MAE: ', mae)

rmse = math.sqrt(mean_squared_error(np.exp(test_data), np.exp(fc)))
print('RMSE: ', rmse)

mape = np.mean(np.abs(np.exp(fc) - np.exp(test_data))/np.abs(np.exp(test_data)))
print('MAPE: {:.2f}%'.format(mape*100))
# Out:
# MSE:  1048973.6014239907
# MAE:  843.7579531508708
# RMSE:  1024.19412292006
# MAPE: 1.03%

# %% [markdown]
# >3.7. 다른 주식 종목 예측해 보기

# %% [markdown]
# ## Tesla

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os

dataset_filepath = os.getenv('HOME') + '/aiffel/stock_prediction/data/TSLA.csv'
df = pd.read_csv(dataset_filepath, index_col='Date', parse_dates=True)
ts = df['Close']

ts.head()
# Out:
# Date
# 2021-02-10    804.820007
# 2021-02-11    811.659973
# 2021-02-12    816.119995
# 2021-02-16    796.219971
# 2021-02-17    798.150024
# Name: Close, dtype: float64

# %% [markdown]
# > 3.2. 각종 전처리 수행

# %%
# 결측치 처리
ts = ts.interpolate(method='time')
ts[ts.isna()]  # Time Series에서 결측치가 있는 부분만 Series로 출력합니다.
# Out:
# Series([], Name: Close, dtype: float64)

# %%
# 로그 변환 시도 
ts_log = np.log(ts)

# %%
from matplotlib.pylab import rcParams
rcParams['figure.figsize'] = 13, 6    # matlab 차트의 기본 크기를 13, 6으로 지정해 줍니다.

# 시계열(time series) 데이터를 차트로 그려 봅시다. 특별히 더 가공하지 않아도 잘 그려집니다.
plt.plot(ts)

# %%
# 결측치가 있다면 이를 보간합니다. 보간 기준은 time을 선택합니다. 
ts=ts.interpolate(method='time')

# 보간 이후 결측치(NaN) 유무를 다시 확인합니다.
print(ts[ts.isna()])

# 다시 그래프를 확인해봅시다!
plt.plot(ts)
# Out:
# Series([], Name: Close, dtype: float64)

# %% [markdown]
# > 3.3. 시계열 안정성 분석

# %%
# 구간의 평균 (이동평균) 과 표준편차(이동표준편차)
def plot_rolling_statistics(timeseries, window=12):
    
    rolmean = timeseries.rolling(window=window).mean()  # 이동평균 시계열
    rolstd = timeseries.rolling(window=window).std()    # 이동표준편차 시계열

     # 원본시계열, 이동평균, 이동표준편차를 plot으로 시각화해 본다.
    orig = plt.plot(timeseries, color='blue',label='Original')    
    mean = plt.plot(rolmean, color='red', label='Rolling Mean')
    std = plt.plot(rolstd, color='black', label='Rolling Std')
    plt.legend(loc='best')
    plt.title('Rolling Mean & Standard Deviation')
    plt.show(block=False)
    
print('슝=3')
# Out:
# 슝=3

# %%
from statsmodels.tsa.stattools import adfuller

def augmented_dickey_fuller_test(timeseries):
    # statsmodels 패키지에서 제공하는 adfuller 메서드를 호출합니다.
    dftest = adfuller(timeseries, autolag='AIC')  
    
    # adfuller 메서드가 리턴한 결과를 정리하여 출력합니다.
    print('Results of Dickey-Fuller Test:')
    dfoutput = pd.Series(dftest[0:4], index=['Test Statistic','p-value','#Lags Used','Number of Observations Used'])
    for key,value in dftest[4].items():
        dfoutput['Critical Value (%s)' % key] = value
    print(dfoutput)
    
print('슝=3')
# Out:
# 슝=3

# %%
# 정성적 그래프 분석
plot_rolling_statistics(ts_log, window=12)

#정량적 Augmented Dicky-Fuller Test
augmented_dickey_fuller_test(ts_log)

#시계열 분해 (Time Series Decomposition)
from statsmodels.tsa.seasonal import seasonal_decompose
decomposition = seasonal_decompose(ts_log, model='multiplicative', period = 30) 

trend = decomposition.trend
seasonal = decomposition.seasonal
residual = decomposition.resid

plt.subplot(411)
plt.plot(ts_log, label='Original')
plt.legend(loc='best')
plt.subplot(412)
plt.plot(trend, label='Trend')
plt.legend(loc='best')
plt.subplot(413)
plt.plot(seasonal,label='Seasonality')
plt.legend(loc='best')
plt.subplot(414)
plt.plot(residual, label='Residuals')
plt.legend(loc='best')
plt.tight_layout()
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                  -1.228461
# p-value                          0.661234
# #Lags Used                       0.000000
# Number of Observations Used    252.000000
# Critical Value (1%)             -3.456569
# Critical Value (5%)             -2.873079
# Critical Value (10%)            -2.572919
# dtype: float64

# %%
augmented_dickey_fuller_test(ts)
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                  -1.291086
# p-value                          0.633240
# #Lags Used                       0.000000
# Number of Observations Used    252.000000
# Critical Value (1%)             -3.456569
# Critical Value (5%)             -2.873079
# Critical Value (10%)            -2.572919
# dtype: float64

# %% [markdown]
# p-value가 0.66 이므로 아직 적합한 데이터가 아니다.

# %% [markdown]
# ### 로그함수로 변환

# %%
plt.plot(ts_log)

# %%
augmented_dickey_fuller_test(ts_log)
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                  -1.228461
# p-value                          0.661234
# #Lags Used                       0.000000
# Number of Observations Used    252.000000
# Critical Value (1%)             -3.456569
# Critical Value (5%)             -2.873079
# Critical Value (10%)            -2.572919
# dtype: float64

# %% [markdown]
# 여전히 p-value는 0.59로 좀 더 낮춰야 한다.

# %% [markdown]
# ### moving average 제거 추세 상쇄하기

# %%
moving_avg = ts_log.rolling(window=12).mean()  # moving average구하기 
plt.plot(ts_log)
plt.plot(moving_avg, color='red')

# %%
ts_log_moving_avg = ts_log - moving_avg # 변화량 제거
ts_log_moving_avg.head(15)
# Out:
# Date
# 2021-02-10         NaN
# 2021-02-11         NaN
# 2021-02-12         NaN
# 2021-02-16         NaN
# 2021-02-17         NaN
# 2021-02-18         NaN
# 2021-02-19         NaN
# 2021-02-22         NaN
# 2021-02-23         NaN
# 2021-02-24         NaN
# 2021-02-25         NaN
# 2021-02-26   -0.114321
# 2021-03-01   -0.043243
# 2021-03-02   -0.074829
# 2021-03-03   -0.105908
# Name: Close, dtype: float64

# %%
ts_log_moving_avg.dropna(inplace=True)
ts_log_moving_avg.head(15)
# Out:
# Date
# 2021-02-26   -0.114321
# 2021-03-01   -0.043243
# 2021-03-02   -0.074829
# 2021-03-03   -0.105908
# 2021-03-04   -0.135099
# 2021-03-05   -0.149566
# 2021-03-08   -0.181841
# 2021-03-09    0.009849
# 2021-03-10    0.007221
# 2021-03-11    0.053261
# 2021-03-12    0.050443
# 2021-03-15    0.067636
# 2021-03-16    0.022600
# 2021-03-17    0.060719
# 2021-03-18   -0.006980
# Name: Close, dtype: float64

# %%
plot_rolling_statistics(ts_log_moving_avg)

# %%
augmented_dickey_fuller_test(ts_log_moving_avg)
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                  -3.581959
# p-value                          0.006115
# #Lags Used                      12.000000
# Number of Observations Used    229.000000
# Critical Value (1%)             -3.459233
# Critical Value (5%)             -2.874245
# Critical Value (10%)            -2.573541
# dtype: float64

# %% [markdown]
# 값이 이제 안정적으로 변함을 확인할 수 있지만 추가적으로 차분을 이용해서 계절성을 상쇄 해야 합니다.

# %% [markdown]
# ## 차분

# %%
ts_log_moving_avg_shift = ts_log_moving_avg.shift()

plt.plot(ts_log_moving_avg, color='blue')
plt.plot(ts_log_moving_avg_shift, color='green')

# %%
ts_log_moving_avg_diff = ts_log_moving_avg - ts_log_moving_avg_shift
ts_log_moving_avg_diff.dropna(inplace=True)
plt.plot(ts_log_moving_avg_diff)

# %%
plot_rolling_statistics(ts_log_moving_avg_diff)

# %%
augmented_dickey_fuller_test(ts_log_moving_avg_diff)
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                -6.477005e+00
# p-value                        1.323498e-08
# #Lags Used                     1.200000e+01
# Number of Observations Used    2.280000e+02
# Critical Value (1%)           -3.459361e+00
# Critical Value (5%)           -2.874302e+00
# Critical Value (10%)          -2.573571e+00
# dtype: float64

# %% [markdown]
# > 3.4. 학습, 테스트 데이터셋 생성

# %%
train_data, test_data = ts_log[:int(len(ts_log)*0.9)], ts_log[int(len(ts_log)*0.9):]
plt.figure(figsize=(10,6))
plt.grid(True)
plt.plot(ts_log, c='r', label='training dataset')  # train_data를 적용하면 그래프가 끊어져 보이므로 자연스러운 연출을 위해 ts_log를 선택
plt.plot(test_data, c='b', label='test dataset')
plt.legend()

# %%
print(ts_log[:2])
print(train_data.shape)
print(test_data.shape)
# Out:
# Date
# 2021-02-10    6.690619
# 2021-02-11    6.699081
# Name: Close, dtype: float64
# (227,)
# (26,)

# %% [markdown]
# > 3.5. 적정 ARIMA 모수 찾기

# %%
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf

plot_acf(ts_log)   # ACF : Autocorrelation 그래프 그리기
plot_pacf(ts_log)  # PACF : Partial Autocorrelation 그래프 그리기
plt.show()

# %%
# 1차 차분 구하기
diff_1 = ts_log.diff(periods=1).iloc[1:]
diff_1.plot(title='Difference 1st')

augmented_dickey_fuller_test(diff_1)

# 혹시 필요한 경우 2차 차분 구하기
diff_2 = diff_1.diff(periods=1).iloc[1:]
diff_2.plot(title='Difference 2nd')

augmented_dickey_fuller_test(diff_2)
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                -1.688748e+01
# p-value                        1.051349e-29
# #Lags Used                     0.000000e+00
# Number of Observations Used    2.510000e+02
# Critical Value (1%)           -3.456674e+00
# Critical Value (5%)           -2.873125e+00
# Critical Value (10%)          -2.572944e+00
# dtype: float64
# Results of Dickey-Fuller Test:
# Test Statistic                -6.943489e+00
# p-value                        1.011002e-09
# #Lags Used                     1.600000e+01
# Number of Observations Used    2.340000e+02
# Critical Value (1%)           -3.458608e+00
# Critical Value (5%)           -2.873972e+00
# Critical Value (10%)          -2.573396e+00
# dtype: float64

# %% [markdown]
# 차분 없이 해도 p-value가 낮게 나오기 때문에 차분은 0으로 둔다.

# %% [markdown]
# >3.6. ARIMA 모델 훈련과 테스트

# %%
import warnings
warnings.filterwarnings('ignore') #경고 무시

from statsmodels.tsa.arima.model import ARIMA
# Build Model
model = ARIMA(train_data, order=(0, 0, 16)) # 모수는 이전 그래프를 참고 
fitted_m = model.fit() 

print(fitted_m.summary())
# Out:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                  Close   No. Observations:                  227
# Model:                ARIMA(0, 0, 16)   Log Likelihood                 431.750
# Date:                Thu, 10 Feb 2022   AIC                           -827.500
# Time:                        06:53:47   BIC                           -765.850
# Sample:                             0   HQIC                          -802.623
#                                 - 227
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          6.6491      0.046    144.171      0.000       6.559       6.740
# ma.L1          1.0853      0.069     15.786      0.000       0.951       1.220
# ma.L2          1.1944      0.091     13.114      0.000       1.016       1.373
# ma.L3          1.2229      0.123      9.971      0.000       0.982       1.463
# ma.L4          1.2067      0.134      9.003      0.000       0.944       1.469
# ma.L5          1.2116      0.155      7.830      0.000       0.908       1.515
# ma.L6          1.2545      0.180      6.957      0.000       0.901       1.608
# ma.L7          1.2984      0.182      7.116      0.000       0.941       1.656
# ma.L8          1.2863      0.180      7.134      0.000       0.933       1.640
# ma.L9          1.2233      0.198      6.180      0.000       0.835       1.611
# ma.L10         1.0910      0.199      5.487      0.000       0.701       1.481
# ma.L11         0.8328      0.196      4.253      0.000       0.449       1.217
# ma.L12         0.7999      0.175      4.576      0.000       0.457       1.142
# ma.L13         0.6293      0.172      3.649      0.000       0.291       0.967
# ma.L14         0.5505      0.157      3.510      0.000       0.243       0.858
# ma.L15         0.4482      0.119      3.771      0.000       0.215       0.681
# ma.L16         0.2369      0.095      2.495      0.013       0.051       0.423
# sigma2         0.0013      0.000     11.767      0.000       0.001       0.001
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.10   Jarque-Bera (JB):                66.72
# Prob(Q):                              0.76   Prob(JB):                         0.00
# Heteroskedasticity (H):               1.10   Skew:                             0.78
# Prob(H) (two-sided):                  0.67   Kurtosis:                         5.15
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %% [markdown]
# 사실 처음에는 그래프로 예측을 했을때 14, 0, 0 으로 예측을 했으나 값이 제대로 나오지 않아서 시행착오 끝에 0, 0, 16을 대입했다.

# %%
# Forecast : 결과가 fc에 담깁니다. 
fc = fitted_m.forecast(len(test_data), alpha=0.05)  # 95% conf
fc = np.array(fc)
# Make as pandas series
fc_series = pd.Series(fc, index=test_data.index)   # 예측결과

# Plot
plt.figure(figsize=(10,5), dpi=100)
plt.plot(train_data, label='training')
plt.plot(test_data, c='b', label='actual price')
plt.plot(fc_series, c='r',label='predicted price')
plt.legend()
plt.show()

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error
import math

mse = mean_squared_error(np.exp(test_data), np.exp(fc))
print('MSE: ', mse)

mae = mean_absolute_error(np.exp(test_data), np.exp(fc))
print('MAE: ', mae)

rmse = math.sqrt(mean_squared_error(np.exp(test_data), np.exp(fc)))
print('RMSE: ', rmse)

mape = np.mean(np.abs(np.exp(fc) - np.exp(test_data))/np.abs(np.exp(test_data)))
print('MAPE: {:.2f}%'.format(mape*100))
# Out:
# MSE:  12758.889031357221
# MAE:  104.01431397544376
# RMSE:  112.9552523407266
# MAPE: 10.87%

# %% [markdown]
# ## Kakao

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os

dataset_filepath = os.getenv('HOME') + '/aiffel/stock_prediction/data/035720.KS.csv'
df = pd.read_csv(dataset_filepath, index_col='Date', parse_dates=True)
ts = df['Close']

ts.head()
# Out:
# Date
# 2021-02-10     97900.0
# 2021-02-15    100400.0
# 2021-02-16    102800.0
# 2021-02-17    101800.0
# 2021-02-18    100200.0
# Name: Close, dtype: float64

# %% [markdown]
# > 3.2. 각종 전처리 수행

# %%
# 결측치 처리
ts = ts.interpolate(method='time')
ts[ts.isna()]  # Time Series에서 결측치가 있는 부분만 Series로 출력합니다.
# Out:
# Series([], Name: Close, dtype: float64)

# %%
# 로그 변환 시도 
ts_log = np.log(ts)

# %%
from matplotlib.pylab import rcParams
rcParams['figure.figsize'] = 13, 6    # matlab 차트의 기본 크기를 13, 6으로 지정해 줍니다.

# 시계열(time series) 데이터를 차트로 그려 봅시다. 특별히 더 가공하지 않아도 잘 그려집니다.
plt.plot(ts)

# %%
# 결측치가 있다면 이를 보간합니다. 보간 기준은 time을 선택합니다. 
ts=ts.interpolate(method='time')

# 보간 이후 결측치(NaN) 유무를 다시 확인합니다.
print(ts[ts.isna()])

# 다시 그래프를 확인해봅시다!
plt.plot(ts)
# Out:
# Series([], Name: Close, dtype: float64)

# %% [markdown]
# > 3.3. 시계열 안정성 분석

# %%
# 구간의 평균 (이동평균) 과 표준편차(이동표준편차)
def plot_rolling_statistics(timeseries, window=12):
    
    rolmean = timeseries.rolling(window=window).mean()  # 이동평균 시계열
    rolstd = timeseries.rolling(window=window).std()    # 이동표준편차 시계열

     # 원본시계열, 이동평균, 이동표준편차를 plot으로 시각화해 본다.
    orig = plt.plot(timeseries, color='blue',label='Original')    
    mean = plt.plot(rolmean, color='red', label='Rolling Mean')
    std = plt.plot(rolstd, color='black', label='Rolling Std')
    plt.legend(loc='best')
    plt.title('Rolling Mean & Standard Deviation')
    plt.show(block=False)
    
print('슝=3')
# Out:
# 슝=3

# %%
from statsmodels.tsa.stattools import adfuller

def augmented_dickey_fuller_test(timeseries):
    # statsmodels 패키지에서 제공하는 adfuller 메서드를 호출합니다.
    dftest = adfuller(timeseries, autolag='AIC')  
    
    # adfuller 메서드가 리턴한 결과를 정리하여 출력합니다.
    print('Results of Dickey-Fuller Test:')
    dfoutput = pd.Series(dftest[0:4], index=['Test Statistic','p-value','#Lags Used','Number of Observations Used'])
    for key,value in dftest[4].items():
        dfoutput['Critical Value (%s)' % key] = value
    print(dfoutput)
    
print('슝=3')
# Out:
# 슝=3

# %%
# 정성적 그래프 분석
plot_rolling_statistics(ts_log, window=12)

#정량적 Augmented Dicky-Fuller Test
augmented_dickey_fuller_test(ts_log)

#시계열 분해 (Time Series Decomposition)
from statsmodels.tsa.seasonal import seasonal_decompose
decomposition = seasonal_decompose(ts_log, model='multiplicative', period = 30) 

trend = decomposition.trend
seasonal = decomposition.seasonal
residual = decomposition.resid

plt.subplot(411)
plt.plot(ts_log, label='Original')
plt.legend(loc='best')
plt.subplot(412)
plt.plot(trend, label='Trend')
plt.legend(loc='best')
plt.subplot(413)
plt.plot(seasonal,label='Seasonality')
plt.legend(loc='best')
plt.subplot(414)
plt.plot(residual, label='Residuals')
plt.legend(loc='best')
plt.tight_layout()
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                  -1.364310
# p-value                          0.599262
# #Lags Used                       7.000000
# Number of Observations Used    238.000000
# Critical Value (1%)             -3.458128
# Critical Value (5%)             -2.873762
# Critical Value (10%)            -2.573283
# dtype: float64

# %%
augmented_dickey_fuller_test(ts)
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                  -0.930802
# p-value                          0.777660
# #Lags Used                       3.000000
# Number of Observations Used    242.000000
# Critical Value (1%)             -3.457664
# Critical Value (5%)             -2.873559
# Critical Value (10%)            -2.573175
# dtype: float64

# %% [markdown]
# p-value가 0.66 이므로 아직 적합한 데이터가 아니다.

# %% [markdown]
# ### 로그함수로 변환

# %%
plt.plot(ts_log)

# %%
augmented_dickey_fuller_test(ts_log)
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                  -1.364310
# p-value                          0.599262
# #Lags Used                       7.000000
# Number of Observations Used    238.000000
# Critical Value (1%)             -3.458128
# Critical Value (5%)             -2.873762
# Critical Value (10%)            -2.573283
# dtype: float64

# %% [markdown]
# 여전히 p-value는 0.59로 좀 더 낮춰야 한다.

# %% [markdown]
# ### moving average 제거 추세 상쇄하기

# %%
moving_avg = ts_log.rolling(window=12).mean()  # moving average구하기 
plt.plot(ts_log)
plt.plot(moving_avg, color='red')

# %%
ts_log_moving_avg = ts_log - moving_avg # 변화량 제거
ts_log_moving_avg.head(15)
# Out:
# Date
# 2021-02-10         NaN
# 2021-02-15         NaN
# 2021-02-16         NaN
# 2021-02-17         NaN
# 2021-02-18         NaN
# 2021-02-19         NaN
# 2021-02-22         NaN
# 2021-02-23         NaN
# 2021-02-24         NaN
# 2021-02-25         NaN
# 2021-02-26         NaN
# 2021-03-02   -0.005919
# 2021-03-03   -0.002537
# 2021-03-04   -0.022727
# 2021-03-05   -0.038533
# Name: Close, dtype: float64

# %%
ts_log_moving_avg.dropna(inplace=True)
ts_log_moving_avg.head(15)
# Out:
# Date
# 2021-03-02   -0.005919
# 2021-03-03   -0.002537
# 2021-03-04   -0.022727
# 2021-03-05   -0.038533
# 2021-03-08   -0.065765
# 2021-03-09   -0.084187
# 2021-03-10   -0.034393
# 2021-03-11    0.008059
# 2021-03-12    0.013258
# 2021-03-15    0.008129
# 2021-03-16    0.009081
# 2021-03-17    0.022043
# 2021-03-18    0.047399
# 2021-03-19    0.036463
# 2021-03-22    0.037454
# Name: Close, dtype: float64

# %%
plot_rolling_statistics(ts_log_moving_avg)

# %%
augmented_dickey_fuller_test(ts_log_moving_avg)
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                  -3.470585
# p-value                          0.008775
# #Lags Used                       3.000000
# Number of Observations Used    231.000000
# Critical Value (1%)             -3.458980
# Critical Value (5%)             -2.874135
# Critical Value (10%)            -2.573482
# dtype: float64

# %% [markdown]
# 값이 이제 안정적으로 변함을 확인할 수 있지만 추가적으로 차분을 이용해서 계절성을 상쇄 해야 합니다.

# %% [markdown]
# ## 차분

# %%
ts_log_moving_avg_shift = ts_log_moving_avg.shift()

plt.plot(ts_log_moving_avg, color='blue')
plt.plot(ts_log_moving_avg_shift, color='green')

# %%
ts_log_moving_avg_diff = ts_log_moving_avg - ts_log_moving_avg_shift
ts_log_moving_avg_diff.dropna(inplace=True)
plt.plot(ts_log_moving_avg_diff)

# %%
plot_rolling_statistics(ts_log_moving_avg_diff)

# %%
augmented_dickey_fuller_test(ts_log_moving_avg_diff)
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                -8.648784e+00
# p-value                        5.183085e-14
# #Lags Used                     2.000000e+00
# Number of Observations Used    2.310000e+02
# Critical Value (1%)           -3.458980e+00
# Critical Value (5%)           -2.874135e+00
# Critical Value (10%)          -2.573482e+00
# dtype: float64

# %% [markdown]
# > 3.4. 학습, 테스트 데이터셋 생성

# %%
train_data, test_data = ts_log[:int(len(ts_log)*0.9)], ts_log[int(len(ts_log)*0.9):]
plt.figure(figsize=(10,6))
plt.grid(True)
plt.plot(ts_log, c='r', label='training dataset')  # train_data를 적용하면 그래프가 끊어져 보이므로 자연스러운 연출을 위해 ts_log를 선택
plt.plot(test_data, c='b', label='test dataset')
plt.legend()

# %%
print(ts_log[:2])
print(train_data.shape)
print(test_data.shape)
# Out:
# Date
# 2021-02-10    11.491702
# 2021-02-15    11.516917
# Name: Close, dtype: float64
# (221,)
# (25,)

# %% [markdown]
# > 3.5. 적정 ARIMA 모수 찾기

# %%
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf

plot_acf(ts_log)   # ACF : Autocorrelation 그래프 그리기
plot_pacf(ts_log)  # PACF : Partial Autocorrelation 그래프 그리기
plt.show()

# %% [markdown]
# 2번째 데이터부터 값들이 ACF 값은 계속해서 하향 곡선을 타며 PACF가 1 이후에는 점차 0에 수렴 한다.

# %%
# 1차 차분 구하기
diff_1 = ts_log.diff(periods=1).iloc[1:]
diff_1.plot(title='Difference 1st')

augmented_dickey_fuller_test(diff_1)

# 혹시 필요한 경우 2차 차분 구하기
diff_2 = diff_1.diff(periods=1).iloc[1:]
diff_2.plot(title='Difference 2nd')

augmented_dickey_fuller_test(diff_2)
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                -7.888119e+00
# p-value                        4.512048e-12
# #Lags Used                     2.000000e+00
# Number of Observations Used    2.420000e+02
# Critical Value (1%)           -3.457664e+00
# Critical Value (5%)           -2.873559e+00
# Critical Value (10%)          -2.573175e+00
# dtype: float64
# Results of Dickey-Fuller Test:
# Test Statistic                -1.070970e+01
# p-value                        3.356490e-19
# #Lags Used                     6.000000e+00
# Number of Observations Used    2.370000e+02
# Critical Value (1%)           -3.458247e+00
# Critical Value (5%)           -2.873814e+00
# Critical Value (10%)          -2.573311e+00
# dtype: float64

# %% [markdown]
# 2차 차분을 했을 때의 값이 잘나오기 때문에 2차 차분까지 값을 넣어도 괜찮다고 생각이 들었다.

# %% [markdown]
# >3.6. ARIMA 모델 훈련과 테스트

# %%
import warnings
warnings.filterwarnings('ignore') #경고 무시

from statsmodels.tsa.arima.model import ARIMA
# Build Model
model = ARIMA(train_data, order=(1, 2, 0)) # 모수는 이전 그래프를 참고 
fitted_m = model.fit() 

print(fitted_m.summary())
# Out:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                  Close   No. Observations:                  221
# Model:                 ARIMA(1, 2, 0)   Log Likelihood                 465.398
# Date:                Thu, 10 Feb 2022   AIC                           -926.795
# Time:                        07:01:14   BIC                           -920.017
# Sample:                             0   HQIC                          -924.058
#                                 - 221
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -0.4154      0.059     -7.024      0.000      -0.531      -0.300
# sigma2         0.0008   5.75e-05     14.516      0.000       0.001       0.001
# ===================================================================================
# Ljung-Box (L1) (Q):                   7.63   Jarque-Bera (JB):                34.82
# Prob(Q):                              0.01   Prob(JB):                         0.00
# Heteroskedasticity (H):               1.13   Skew:                            -0.01
# Prob(H) (two-sided):                  0.61   Kurtosis:                         4.95
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %%
# Forecast : 결과가 fc에 담깁니다. 
fc = fitted_m.forecast(len(test_data), alpha=0.05)  # 95% conf
fc = np.array(fc)
# Make as pandas series
fc_series = pd.Series(fc, index=test_data.index)   # 예측결과

# Plot
plt.figure(figsize=(10,5), dpi=100)
plt.plot(train_data, label='training')
plt.plot(test_data, c='b', label='actual price')
plt.plot(fc_series, c='r',label='predicted price')
plt.legend()
plt.show()

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error
import math

mse = mean_squared_error(np.exp(test_data), np.exp(fc))
print('MSE: ', mse)

mae = mean_absolute_error(np.exp(test_data), np.exp(fc))
print('MAE: ', mae)

rmse = math.sqrt(mean_squared_error(np.exp(test_data), np.exp(fc)))
print('RMSE: ', rmse)

mape = np.mean(np.abs(np.exp(fc) - np.exp(test_data))/np.abs(np.exp(test_data)))
print('MAPE: {:.2f}%'.format(mape*100))
# Out:
# MSE:  93020544.46756051
# MAE:  9142.674829052266
# RMSE:  9644.715883195342
# MAPE: 10.03%

# %% [markdown]
# ## 현대

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os

dataset_filepath = os.getenv('HOME') + '/aiffel/stock_prediction/data/HYMTF.csv'
df = pd.read_csv(dataset_filepath, index_col='Date', parse_dates=True)
ts = df['Close']

ts.head()
# Out:
# Date
# 2021-02-10    53.500000
# 2021-02-11    54.790001
# 2021-02-12    54.650002
# 2021-02-16    53.000000
# 2021-02-17    52.630001
# Name: Close, dtype: float64

# %% [markdown]
# > 3.2. 각종 전처리 수행

# %%
# 결측치 처리
ts = ts.interpolate(method='time')
ts[ts.isna()]  # Time Series에서 결측치가 있는 부분만 Series로 출력합니다.
# Out:
# Series([], Name: Close, dtype: float64)

# %%
# 로그 변환 시도 
ts_log = np.log(ts)

# %%
from matplotlib.pylab import rcParams
rcParams['figure.figsize'] = 13, 6    # matlab 차트의 기본 크기를 13, 6으로 지정해 줍니다.

# 시계열(time series) 데이터를 차트로 그려 봅시다. 특별히 더 가공하지 않아도 잘 그려집니다.
plt.plot(ts)

# %%
# 결측치가 있다면 이를 보간합니다. 보간 기준은 time을 선택합니다. 
ts=ts.interpolate(method='time')

# 보간 이후 결측치(NaN) 유무를 다시 확인합니다.
print(ts[ts.isna()])

# 다시 그래프를 확인해봅시다!
plt.plot(ts)
# Out:
# Series([], Name: Close, dtype: float64)

# %% [markdown]
# > 3.3. 시계열 안정성 분석

# %%
# 구간의 평균 (이동평균) 과 표준편차(이동표준편차)
def plot_rolling_statistics(timeseries, window=12):
    
    rolmean = timeseries.rolling(window=window).mean()  # 이동평균 시계열
    rolstd = timeseries.rolling(window=window).std()    # 이동표준편차 시계열

     # 원본시계열, 이동평균, 이동표준편차를 plot으로 시각화해 본다.
    orig = plt.plot(timeseries, color='blue',label='Original')    
    mean = plt.plot(rolmean, color='red', label='Rolling Mean')
    std = plt.plot(rolstd, color='black', label='Rolling Std')
    plt.legend(loc='best')
    plt.title('Rolling Mean & Standard Deviation')
    plt.show(block=False)
    
print('슝=3')
# Out:
# 슝=3

# %%
from statsmodels.tsa.stattools import adfuller

def augmented_dickey_fuller_test(timeseries):
    # statsmodels 패키지에서 제공하는 adfuller 메서드를 호출합니다.
    dftest = adfuller(timeseries, autolag='AIC')  
    
    # adfuller 메서드가 리턴한 결과를 정리하여 출력합니다.
    print('Results of Dickey-Fuller Test:')
    dfoutput = pd.Series(dftest[0:4], index=['Test Statistic','p-value','#Lags Used','Number of Observations Used'])
    for key,value in dftest[4].items():
        dfoutput['Critical Value (%s)' % key] = value
    print(dfoutput)
    
print('슝=3')
# Out:
# 슝=3

# %%
# 정성적 그래프 분석
plot_rolling_statistics(ts_log, window=12)

#정량적 Augmented Dicky-Fuller Test
augmented_dickey_fuller_test(ts_log)

#시계열 분해 (Time Series Decomposition)
from statsmodels.tsa.seasonal import seasonal_decompose
decomposition = seasonal_decompose(ts_log, model='multiplicative', period = 30) 

trend = decomposition.trend
seasonal = decomposition.seasonal
residual = decomposition.resid

plt.subplot(411)
plt.plot(ts_log, label='Original')
plt.legend(loc='best')
plt.subplot(412)
plt.plot(trend, label='Trend')
plt.legend(loc='best')
plt.subplot(413)
plt.plot(seasonal,label='Seasonality')
plt.legend(loc='best')
plt.subplot(414)
plt.plot(residual, label='Residuals')
plt.legend(loc='best')
plt.tight_layout()
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                  -1.524592
# p-value                          0.521313
# #Lags Used                       3.000000
# Number of Observations Used    249.000000
# Critical Value (1%)             -3.456888
# Critical Value (5%)             -2.873219
# Critical Value (10%)            -2.572994
# dtype: float64

# %%
augmented_dickey_fuller_test(ts)
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                  -1.658324
# p-value                          0.452703
# #Lags Used                       3.000000
# Number of Observations Used    249.000000
# Critical Value (1%)             -3.456888
# Critical Value (5%)             -2.873219
# Critical Value (10%)            -2.572994
# dtype: float64

# %% [markdown]
# p-value가 0.66 이므로 아직 적합한 데이터가 아니다.

# %% [markdown]
# ### 로그함수로 변환

# %%
plt.plot(ts_log)

# %%
augmented_dickey_fuller_test(ts_log)
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                  -1.524592
# p-value                          0.521313
# #Lags Used                       3.000000
# Number of Observations Used    249.000000
# Critical Value (1%)             -3.456888
# Critical Value (5%)             -2.873219
# Critical Value (10%)            -2.572994
# dtype: float64

# %% [markdown]
# 여전히 p-value는 0.59로 좀 더 낮춰야 한다.

# %% [markdown]
# ### moving average 제거 추세 상쇄하기

# %%
moving_avg = ts_log.rolling(window=12).mean()  # moving average구하기 
plt.plot(ts_log)
plt.plot(moving_avg, color='red')

# %%
ts_log_moving_avg = ts_log - moving_avg # 변화량 제거
ts_log_moving_avg.head(15)
# Out:
# Date
# 2021-02-10         NaN
# 2021-02-11         NaN
# 2021-02-12         NaN
# 2021-02-16         NaN
# 2021-02-17         NaN
# 2021-02-18         NaN
# 2021-02-19         NaN
# 2021-02-22         NaN
# 2021-02-23         NaN
# 2021-02-24         NaN
# 2021-02-25         NaN
# 2021-02-26   -0.069900
# 2021-03-01   -0.026215
# 2021-03-02   -0.040528
# 2021-03-03   -0.013500
# Name: Close, dtype: float64

# %%
ts_log_moving_avg.dropna(inplace=True)
ts_log_moving_avg.head(15)
# Out:
# Date
# 2021-02-26   -0.069900
# 2021-03-01   -0.026215
# 2021-03-02   -0.040528
# 2021-03-03   -0.013500
# 2021-03-04   -0.048783
# 2021-03-05   -0.057861
# 2021-03-08   -0.054582
# 2021-03-09   -0.022388
# 2021-03-10   -0.022857
# 2021-03-11   -0.012501
# 2021-03-12   -0.006286
# 2021-03-15   -0.011535
# 2021-03-16   -0.007846
# 2021-03-17    0.004400
# 2021-03-18    0.044406
# Name: Close, dtype: float64

# %%
plot_rolling_statistics(ts_log_moving_avg)

# %%
augmented_dickey_fuller_test(ts_log_moving_avg)
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                -5.943712e+00
# p-value                        2.229706e-07
# #Lags Used                     2.000000e+00
# Number of Observations Used    2.390000e+02
# Critical Value (1%)           -3.458011e+00
# Critical Value (5%)           -2.873710e+00
# Critical Value (10%)          -2.573256e+00
# dtype: float64

# %% [markdown]
# 값이 이제 안정적으로 변함을 확인할 수 있지만 추가적으로 차분을 이용해서 계절성을 상쇄 해야 합니다.

# %% [markdown]
# ## 차분

# %%
ts_log_moving_avg_shift = ts_log_moving_avg.shift()

plt.plot(ts_log_moving_avg, color='blue')
plt.plot(ts_log_moving_avg_shift, color='green')

# %%
ts_log_moving_avg_diff = ts_log_moving_avg - ts_log_moving_avg_shift
ts_log_moving_avg_diff.dropna(inplace=True)
plt.plot(ts_log_moving_avg_diff)

# %%
plot_rolling_statistics(ts_log_moving_avg_diff)

# %%
augmented_dickey_fuller_test(ts_log_moving_avg_diff)
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                -6.876519e+00
# p-value                        1.469841e-09
# #Lags Used                     1.200000e+01
# Number of Observations Used    2.280000e+02
# Critical Value (1%)           -3.459361e+00
# Critical Value (5%)           -2.874302e+00
# Critical Value (10%)          -2.573571e+00
# dtype: float64

# %% [markdown]
# > 3.4. 학습, 테스트 데이터셋 생성

# %%
train_data, test_data = ts_log[:int(len(ts_log)*0.9)], ts_log[int(len(ts_log)*0.9):]
plt.figure(figsize=(10,6))
plt.grid(True)
plt.plot(ts_log, c='r', label='training dataset')  # train_data를 적용하면 그래프가 끊어져 보이므로 자연스러운 연출을 위해 ts_log를 선택
plt.plot(test_data, c='b', label='test dataset')
plt.legend()

# %%
print(ts_log[:2])
print(train_data.shape)
print(test_data.shape)
# Out:
# Date
# 2021-02-10    3.979682
# 2021-02-11    4.003508
# Name: Close, dtype: float64
# (227,)
# (26,)

# %% [markdown]
# > 3.5. 적정 ARIMA 모수 찾기

# %%
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf

plot_acf(ts_log)   # ACF : Autocorrelation 그래프 그리기
plot_pacf(ts_log)  # PACF : Partial Autocorrelation 그래프 그리기
plt.show()

# %% [markdown]
# ACF 그래프의 경우엔 꾸준히 하향곡선을 타고 있고 PACF그래프에서는 p : 15부터 모두 0에 수렴한다.

# %%
# 1차 차분 구하기
diff_1 = ts_log.diff(periods=1).iloc[1:]
diff_1.plot(title='Difference 1st')

augmented_dickey_fuller_test(diff_1)

# 혹시 필요한 경우 2차 차분 구하기
diff_2 = diff_1.diff(periods=1).iloc[1:]
diff_2.plot(title='Difference 2nd')

augmented_dickey_fuller_test(diff_2)
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                -1.034594e+01
# p-value                        2.610998e-18
# #Lags Used                     2.000000e+00
# Number of Observations Used    2.490000e+02
# Critical Value (1%)           -3.456888e+00
# Critical Value (5%)           -2.873219e+00
# Critical Value (10%)          -2.572994e+00
# dtype: float64
# Results of Dickey-Fuller Test:
# Test Statistic                -8.025072e+00
# p-value                        2.027637e-12
# #Lags Used                     1.200000e+01
# Number of Observations Used    2.380000e+02
# Critical Value (1%)           -3.458128e+00
# Critical Value (5%)           -2.873762e+00
# Critical Value (10%)          -2.573283e+00
# dtype: float64

# %% [markdown]
# 1차 차분만 했을때 p-value의 값이 굉장히 잘나왔다.

# %% [markdown]
# >3.6. ARIMA 모델 훈련과 테스트

# %%
import warnings
warnings.filterwarnings('ignore') #경고 무시

from statsmodels.tsa.arima.model import ARIMA
# Build Model
model = ARIMA(train_data, order=(15, 1, 0)) # 모수는 이전 그래프를 참고 
fitted_m = model.fit() 

print(fitted_m.summary())
# Out:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                  Close   No. Observations:                  227
# Model:                ARIMA(15, 1, 0)   Log Likelihood                 600.317
# Date:                Thu, 10 Feb 2022   AIC                          -1168.635
# Time:                        07:49:33   BIC                          -1113.906
# Sample:                             0   HQIC                         -1146.549
#                                 - 227
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -0.0342      0.071     -0.479      0.632      -0.174       0.106
# ar.L2          0.0015      0.064      0.023      0.982      -0.123       0.126
# ar.L3         -0.1071      0.070     -1.527      0.127      -0.245       0.030
# ar.L4         -0.0759      0.071     -1.071      0.284      -0.215       0.063
# ar.L5         -0.0600      0.070     -0.862      0.389      -0.196       0.076
# ar.L6          0.0047      0.079      0.059      0.953      -0.150       0.160
# ar.L7         -0.0084      0.069     -0.123      0.902      -0.143       0.126
# ar.L8          0.0080      0.076      0.106      0.915      -0.140       0.156
# ar.L9         -0.0928      0.082     -1.131      0.258      -0.254       0.068
# ar.L10        -0.0493      0.074     -0.665      0.506      -0.195       0.096
# ar.L11         0.0539      0.081      0.666      0.506      -0.105       0.213
# ar.L12         0.0752      0.078      0.962      0.336      -0.078       0.228
# ar.L13        -0.0640      0.076     -0.847      0.397      -0.212       0.084
# ar.L14         0.0266      0.073      0.364      0.716      -0.117       0.170
# ar.L15        -0.0497      0.076     -0.652      0.515      -0.199       0.100
# sigma2         0.0003   2.71e-05     10.638      0.000       0.000       0.000
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.03   Jarque-Bera (JB):                 1.93
# Prob(Q):                              0.85   Prob(JB):                         0.38
# Heteroskedasticity (H):               0.58   Skew:                            -0.20
# Prob(H) (two-sided):                  0.02   Kurtosis:                         3.21
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %%
# Forecast : 결과가 fc에 담깁니다. 
fc = fitted_m.forecast(len(test_data), alpha=0.05)  # 95% conf
fc = np.array(fc)
# Make as pandas series
fc_series = pd.Series(fc, index=test_data.index)   # 예측결과

# Plot
plt.figure(figsize=(10,5), dpi=100)
plt.plot(train_data, label='training')
plt.plot(test_data, c='b', label='actual price')
plt.plot(fc_series, c='r',label='predicted price')
plt.legend()
plt.show()

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error
import math

mse = mean_squared_error(np.exp(test_data), np.exp(fc))
print('MSE: ', mse)

mae = mean_absolute_error(np.exp(test_data), np.exp(fc))
print('MAE: ', mae)

rmse = math.sqrt(mean_squared_error(np.exp(test_data), np.exp(fc)))
print('RMSE: ', rmse)

mape = np.mean(np.abs(np.exp(fc) - np.exp(test_data))/np.abs(np.exp(test_data)))
print('MAPE: {:.2f}%'.format(mape*100))
# Out:
# MSE:  1.7175587333218123
# MAE:  1.1063707245468526
# RMSE:  1.310556650176486
# MAPE: 2.76%

# %% [markdown]
# > **4. 회고**
# -

# %% [markdown]
# > 4.1 결과 평가

# %% [markdown]
# 생각보다 ARIMA의 성능이 좋은것인지 MAPE의 값이 같은 값으로 예측을 해도 값이 20% 정도로 나와서 시행착오에 드는 시간이 많이 절약됐다.
# 삼성정도로 정밀한 예측을 하고싶었는데, 생각보다 값이 제대로 나오지 않아서 고민을 많이 해봤는데 추세의 변동이 커서라고 예측했다.
# 현대 같은 경우는 2.76% 라는 준수한 퍼센트가 나왔음에도 초기 예측은 몰라도 이후엔 많이 다른 모습을 보여준다...

# %% [markdown]
# > 4.2 어려웠던 점

# %% [markdown]
# 최근에 경향이 바뀐 경우에는 생각보다 값이 안나와서 많은 시행착오를 해야했다.
